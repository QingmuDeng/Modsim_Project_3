# %%
# %matplotlib notebook
from modsim import *
import matplotlib.pyplot as plt
import numpy as np

# %%
newfig()
ind = [1, 2, 4, 5, 7, 8]
height = [89.525894, 104.143188, 94.919174, 83.628419, 28.396240, 18.350748] #, 76.907172, 90.864649]
figure = plt.subplot()
plt.show(block=True)
x_high, y_high, vy_high  = plt.bar(ind[::2], height[::2], width=1, label = 'Increase')
x_low, y_low, vy_low  = plt.bar(ind[1::2], height[1::2], width=1, label = 'Decrease')
x_high.set_facecolor('r')
x_low.set_facecolor('b')
y_high.set_facecolor('r')
y_low.set_facecolor('b')
vy_high.set_facecolor('r')
vy_low.set_facecolor('b')
# vx_high.set_facecolor('r')
# vx_low.set_facecolor('b')
figure.set_xticks([1.5, 4.5, 7.5])#, 10.5])
figure.set_xticklabels(['X', 'Y', 'VY'])#, 'VX'])
decorate(title='2% Variation in Initial Conditions',
         xlabel='Condition Changed',
         ylabel='Time of Initial Divergence (seconds)')
#plt.legend(['Increase','Decrease'], loc='upper left')
#legend([y_high], ["Increase"])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
savefig('2%bar.eps')
# Out:
# Saving figure to file 2%bar.eps

# %%
ind[1::2]
# Out:
# [2, 5, 8]

# %%
newfig()
ind = [1, 2, 4, 5, 7, 8]
height = [85.274956, 23.010662, 86.288086, 65.464427, 11.262500, 6.255620] #, 76.907172, 90.864649]
figure = plt.subplot()
plt.show(block=True)
x_high, y_high, vy_high  = plt.bar(ind[::2], height[::2], width=1, label = 'Increase')
x_low, y_low, vy_low  = plt.bar(ind[1::2], height[1::2], width=1, label = 'Decrease')
x_high.set_facecolor('r')
x_low.set_facecolor('b')
y_high.set_facecolor('r')
y_low.set_facecolor('b')
vy_high.set_facecolor('r')
vy_low.set_facecolor('b')
# vx_high.set_facecolor('r')
# vx_low.set_facecolor('b')
figure.set_xticks([1.5, 4.5, 7.5])#, 10.5])
figure.set_xticklabels(['X', 'Y', 'VY'])#, 'VX'])
decorate(title='5% Variation in Initial Conditions',
         xlabel='Condition Changed',
         ylabel='Time of Initial Divergence (seconds)')
#plt.legend(['Increase','Decrease'], loc='upper left')
#legend([y_high], ["Increase"])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
savefig('5%bar.eps')
# Out:
# Saving figure to file 5%bar.eps

# %%
newfig()
ind = [1, 2, 4, 5, 7, 8]
height = [6.601381, 6.088154, 28.851878, 22.725423, 3.715665, 3.093249] #, 76.907172, 90.864649]
figure = plt.subplot()
plt.show(block=True)
x_high, y_high, vy_high  = plt.bar(ind[::2], height[::2], width=1, label = 'Increase')
x_low, y_low, vy_low  = plt.bar(ind[1::2], height[1::2], width=1, label = 'Decrease')
x_high.set_facecolor('r')
x_low.set_facecolor('b')
y_high.set_facecolor('r')
y_low.set_facecolor('b')
vy_high.set_facecolor('r')
vy_low.set_facecolor('b')
# vx_high.set_facecolor('r')
# vx_low.set_facecolor('b')
figure.set_xticks([1.5, 4.5, 7.5])#, 10.5])
figure.set_xticklabels(['X', 'Y', 'VY'])#, 'VX'])
decorate(title='10% Variation in Initial Conditions',
         xlabel='Condition Changed',
         ylabel='Time of Initial Divergence (seconds)')
#plt.legend(['Increase','Decrease'], loc='upper left')
#legend([y_high], ["Increase"])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="688">

# %%
savefig('10%bar.eps')
# Out:
# Saving figure to file 10%bar.eps

# %%
newfig()
ind = np.arange(1, 4)
height = np.random.randint(0, 100, size = 3)
figure = plt.subplot()
plt.show(block=True)
ab, cd, ef = plt.bar(ind, height)
ab.set_facecolor('r')
cd.set_facecolor('b')
ef.set_facecolor('g')
figure.set_xticks(ind)
figure.set_xticklabels(['red', 'blue', 'green'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# ## Bar Graph

# %%
height = [89.525894, 104.143188, 94.919174, 83.628419, 28.396240, 18.350748,
          85.274956, 23.010662, 86.288086, 65.464427, 11.262500, 6.255620,
          6.601381, 6.088154, 28.851878, 22.725423, 3.715665, 3.093249]
percent_change = [.02, .02, .02, .02, .02, .02,
                  .05, .05, .05, .05, .05, .05,
                  .1, .1, .1, .1, .1, .1,]

# %%
newfig()
plot([2, 5, 10], [89.525894, 85.274956, 6.601381], Color='m', marker='o', linestyle=':') #X Increase
plot([2, 5, 10], [104.143188, 23.010662, 6.088154], Color='c', marker='o', linestyle=':') #X Decrease
plot([2, 5, 10], [94.919174, 86.288086, 28.851878], Color='m', marker='p', linestyle=':') #Y Increase
plot([2, 5, 10], [83.628419, 65.464427, 22.725423], Color='c', marker='p', linestyle=':') #Y Decrease
plot([2, 5, 10], [28.396240, 11.262500, 3.715665], Color='m', marker='v', linestyle=':') #VY Increase
plot([2, 5, 10], [18.350748, 6.255620, 3.093249], Color='c', marker='v', linestyle=':') #VY Decrease

plt.scatter(-5, -5, Color='k', marker='o', label='X')
plt.scatter(-5, -5, Color='k', marker='p', label='Y')
plt.scatter(-5, -5, Color='k', marker='v', label='Vy')
plt.bar(-5, 1, Color='m', label='increase')
plt.bar(-5, 1, Color='c', label='decrease')


decorate(title='Time of Initial Divergence vs Percentage of Change',
         xlabel='Percentage of Change(%)',
         ylabel='Time of Initial Divergence (seconds)')

xlim([0, 12])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 12)

# %%
savefig('scatterplot.eps')
# Out:
# Saving figure to file scatterplot.eps
